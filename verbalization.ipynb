# %% [markdown]
# # Step by step

# %%
a = [('http://demo.fiz-karlsruhe.de/matwerk/E461321', 'dcterms:description', '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"'), ('http://demo.fiz-karlsruhe.de/matwerk/E487592', 'dcterms:description', '" pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"'), ('http://demo.fiz-karlsruhe.de/matwerk/E469997', 'dcterms:description', '"browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."'), ('http://demo.fiz-karlsruhe.de/matwerk/E483654', 'dcterms:description', '"The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "'), ('http://demo.fiz-karlsruhe.de/matwerk/E435779', 'dcterms:description', '"S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It also is a program (sphinx) to perform such simulations using density-functional theory, and k.p theory. In addition, the package offers dozens of specialized programs (add-ons) for smaller tasks related to setup, analysis, post-processing, and other types of simulations."'), ('http://demo.fiz-karlsruhe.de/matwerk/E473879', 'dcterms:description', '"Python package to automatically build the reference set for the training of Neural Network Potentials (NNPs), and eventually other machine-learned potentials, in an automated, data-driven fashion."'), ('http://demo.fiz-karlsruhe.de/matwerk/E482672', 'dcterms:description', '"Read, write and analyze MD trajectories with only a few lines of Python code."'), ('http://demo.fiz-karlsruhe.de/matwerk/E491546', 'dcterms:description', '"tool for creating CALPHAD databases and evaluating the uncertainty of CALPHAD models."'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E481691', 'dcterms:description', '"Pizza.py is a loosely integrated collection of tools, many of which provide pre- and post-processing capability for the LAMMPS molecular dynamics, ChemCell cell modeling, and SPPARKS kinetic Monte Carlo packages. There are tools to create input files, convert between file formats, process log and dump files, create plots, and visualize and animate simulation snapshots. "'), ('http://demo.fiz-karlsruhe.de/matwerk/E497507', 'dcterms:description', '"Python library for data mining the properties of materials."'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E7556')]

a[0]
# Out:
# ('http://demo.fiz-karlsruhe.de/matwerk/E461321',
#  'dcterms:description',
#  '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"')

# %%
a[0][0]
# Out:
# 'http://demo.fiz-karlsruhe.de/matwerk/E461321'

# %%
import pandas as pd

# 加载Excel文件
entity_df = pd.read_excel('entity_list.xlsx')


# 遍历列表中的每个元组
for i, (entity_uri, predicate, description) in enumerate(a):
    # 在DataFrame中查找匹配的'entity_uri'
    row = entity_df[entity_df['entity_uri'] == entity_uri]
    
    # 如果找到了匹配项，替换元组中的'entity_uri'
    if not row.empty:
        a[i] = (row['entity_readable'].values[0], predicate, description)
    else:
        print(f"未找到{entity_uri}的匹配项")

# 输出修改后的列表
print(a)
# Out:
# [('OVITO basic', 'dcterms:description', '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"'), ('Yet another force field', 'dcterms:description', '" pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"'), ('Graphical Interface for Materials Simulations', 'dcterms:description', '"browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."'), ('freud', 'dcterms:description', '"The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "'), ('S/PHI/nX', 'dcterms:description', '"S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It 
# ...

# %%
import pandas as pd

# 加载 Excel 文件
relation_df = pd.read_excel('relation_list.xlsx')


# 替换三元组中的第二个元素
for i, tuple in enumerate(a):
    # 查找与三元组第二个元素匹配的行
    match_row = relation_df[relation_df['Predicate with NS'] == tuple[1]]
    
    # 如果找到匹配项，则替换
    if not match_row.empty:
        # 获取 'relationship_readable' 的值
        readable_value = match_row['relationship_readable'].values[0]
        # 替换三元组中的第二个元素
        a[i] = (tuple[0], readable_value, tuple[2])

# 输出替换后的列表
print(a)
# Out:
# [('OVITO basic', 'has  description', '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"'), ('Yet another force field', 'has  description', '" pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"'), ('Graphical Interface for Materials Simulations', 'has  description', '"browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."'), ('freud', 'has  description', '"The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "'), ('S/PHI/nX', 'has  description', '"S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It also is a progr
# ...

# %%
import pandas as pd

# 加载 "entity_list.xlsx" 文件
entity_df = pd.read_excel('entity_list.xlsx')

# 遍历 'a' 列表中的每个三元组
for i, tuple in enumerate(a):
    # 查找 'entity_uri' 列中与三元组第三个元素相匹配的行
    row = entity_df[entity_df['entity_uri'] == tuple[2]]

    # 如果找到匹配行，用 'entity_readable' 的值替换三元组的第三个元素
    if not row.empty:
        a[i] = (tuple[0], tuple[1], row['entity_readable'].values[0])

# 输出修改后的 'a' 列表
print(a)
# Out:
# [('OVITO basic', 'has  description', '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"'), ('Yet another force field', 'has  description', '" pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"'), ('Graphical Interface for Materials Simulations', 'has  description', '"browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."'), ('freud', 'has  description', '"The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "'), ('S/PHI/nX', 'has  description', '"S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It also is a progr
# ...

# %%
a = [('http://demo.fiz-karlsruhe.de/matwerk/E461321', 'dcterms:description', '"visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"'), ('http://demo.fiz-karlsruhe.de/matwerk/E487592', 'dcterms:description', '" pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"'), ('http://demo.fiz-karlsruhe.de/matwerk/E469997', 'dcterms:description', '"browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."'), ('http://demo.fiz-karlsruhe.de/matwerk/E483654', 'dcterms:description', '"The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "'), ('http://demo.fiz-karlsruhe.de/matwerk/E435779', 'dcterms:description', '"S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It also is a program (sphinx) to perform such simulations using density-functional theory, and k.p theory. In addition, the package offers dozens of specialized programs (add-ons) for smaller tasks related to setup, analysis, post-processing, and other types of simulations."'), ('http://demo.fiz-karlsruhe.de/matwerk/E473879', 'dcterms:description', '"Python package to automatically build the reference set for the training of Neural Network Potentials (NNPs), and eventually other machine-learned potentials, in an automated, data-driven fashion."'), ('http://demo.fiz-karlsruhe.de/matwerk/E482672', 'dcterms:description', '"Read, write and analyze MD trajectories with only a few lines of Python code."'), ('http://demo.fiz-karlsruhe.de/matwerk/E491546', 'dcterms:description', '"tool for creating CALPHAD databases and evaluating the uncertainty of CALPHAD models."'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E12629', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14204', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E14531', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E21101', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E1001'), ('http://demo.fiz-karlsruhe.de/matwerk/E481691', 'dcterms:description', '"Pizza.py is a loosely integrated collection of tools, many of which provide pre- and post-processing capability for the LAMMPS molecular dynamics, ChemCell cell modeling, and SPPARKS kinetic Monte Carlo packages. There are tools to create input files, convert between file formats, process log and dump files, create plots, and visualize and animate simulation snapshots. "'), ('http://demo.fiz-karlsruhe.de/matwerk/E497507', 'dcterms:description', '"Python library for data mining the properties of materials."'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:requiredTool', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:hasRelatedResource', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:relatedParticipantProject', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'mwo:description', 'http://demo.fiz-karlsruhe.de/matwerk/E7556'), ('http://demo.fiz-karlsruhe.de/matwerk/E31382', 'dcterms:description', 'http://demo.fiz-karlsruhe.de/matwerk/E7556')]

a[-1]
# Out:
# ('http://demo.fiz-karlsruhe.de/matwerk/E31382',
#  'dcterms:description',
#  'http://demo.fiz-karlsruhe.de/matwerk/E7556')

# %%
import pandas as pd

# 加载 "entity_list.xlsx" 文件
entity_df = pd.read_excel('entity_list.xlsx')
relation_df = pd.read_excel('relation_list.xlsx')

# 遍历 'a' 列表中的每个三元组
for i, tuple in enumerate(a):
    # 查找 'entity_uri' 列中与三元组第一个元素相匹配的行
    row = entity_df[entity_df['entity_uri'] == tuple[0]]

    # 如果找到匹配行，用 'entity_readable' 的值替换三元组的第一个元素
    if not row.empty:
        a[i] = (row['entity_readable'].values[0], tuple[1],tuple[2])


# 替换三元组中的第二个元素
for i, tuple in enumerate(a):
    # 查找与三元组第二个元素匹配的行
    match_row = relation_df[relation_df['Predicate with NS'] == tuple[1]]
    
    # 如果找到匹配项，则替换
    if not match_row.empty:
        # 获取 'relationship_readable' 的值
        readable_value = match_row['relationship_readable'].values[0]
        # 替换三元组中的第二个元素
        a[i] = (tuple[0], readable_value, tuple[2])


# 加载 "entity_list.xlsx" 文件
entity_df = pd.read_excel('entity_list.xlsx')

# 遍历 'a' 列表中的每个三元组
for i, tuple in enumerate(a):
    # 查找 'entity_uri' 列中与三元组第三个元素相匹配的行
    row = entity_df[entity_df['entity_uri'] == tuple[2]]

    # 如果找到匹配行，用 'entity_readable' 的值替换三元组的第三个元素
    if not row.empty:
        a[i] = (tuple[0], tuple[1], row['entity_readable'].values[0])



# Join each triple into a single string
a = [' '.join(triple) for triple in a]

# 输出修改后的 'a' 列表
print(a)
# Out:
# ['OVITO basic has  description "visualization and analysis for data generated in MD, atomistic Monte-Carlo and other particle-based simulations"', 'Yet another force field has  description " pythonic force-field (FF) code used at the Center for Molecular Modeling (CMM) to test-drive new FF models"', 'Graphical Interface for Materials Simulations has  description "browser-based toolbox for electronic structure codes and supports the generation of input files for first-principles electronic structure calculations and workflows, as well as the analysis and visualization of the resulting data extracted from the output files."', 'freud has  description "The freud Python library provides a simple, flexible, powerful set of tools for analyzing trajectories obtained from molecular dynamics or Monte Carlo simulations. "', 'S/PHI/nX has  description "S/PHI/nX is a C++ library for materials simulation, mostly electronic-structure theory. It also is a program (sphinx) to perform such simulations
# ...

# %% [markdown]
# # Verbalization

# %%
import pandas as pd
import ast  # For safely evaluating strings containing Python literals


# Load the initial DataFrame
df_verbalization = pd.read_excel('for_verbalisation.xlsx')

# Ensure the 'Processed Triples' column exists
if 'Processed Triples' not in df_verbalization.columns:
    df_verbalization['Processed Triples'] = pd.NA  # Initialize with NA values

# Load supporting DataFrames
entity_df = pd.read_excel('entity_list.xlsx')
relation_df = pd.read_excel('relation_list.xlsx')

for index, row in df_verbalization.iterrows():
    try:
        triples = ast.literal_eval(row['Found Triples'])
    except (ValueError, SyntaxError):
        df_verbalization.at[index, 'Processed Triples'] = 'Invalid format'
        continue

    processed_triples = []
    for triple in triples:
        entity_row = entity_df[entity_df['entity_uri'] == triple[0]]
        if not entity_row.empty:
            triple = (entity_row['entity_readable'].iloc[0], triple[1], triple[2])

        relation_row = relation_df[relation_df['Predicate with NS'] == triple[1]]
        if not relation_row.empty:
            triple = (triple[0], relation_row['relationship_readable'].iloc[0], triple[2])

        entity_row = entity_df[entity_df['entity_uri'] == triple[2]]
        if not entity_row.empty:
            triple = (triple[0], triple[1], entity_row['entity_readable'].iloc[0])

        processed_triples.append(triple)

    # Convert all elements to strings before joining
    processed_triples_string = [' '.join(map(str, triple)) for triple in processed_triples]
    df_verbalization.at[index, 'Processed Triples'] = '; '.join(processed_triples_string)

# %%
df_verbalization
# Out:
#                                                  Text  \
# 0   Who is working in the Computational Materials ...
# 1   What are the research projects associated to E...
# 2    Who are the contributors of the data "datasets"?
# 3   Who is working with Researcher "Ebrahim Norouz...
# 4             Who is the email address of "ParaView"?
# 5        What are the affiliations of Volker Hofmann?
# 6   What is "Molecular Dynamics" Software? List th...
# 7   What are pre- and post-processing tools for MD...
# 8   What are some workflow environments for comput...
# 9                           How should I cite pyiron?
# 10  Where can I find a list of interatomic potenti...
# 11  What are python libraries used for calculating...
# 12   What are the electronic lab notebooks available?
# 13  What are the software for Molecular Dynamics (...
# 14   What are the ontologies in nanomaterials domain?
# 15                                    What is DAMASK?
# ...

# %%
df_template = pd.read_excel('output template.xlsx')
# delete the 'Related Triples '
df_template.drop('Related Triples ', axis=1, inplace=True)
# Creat a new column named "Related Triples" "Context" after the "Ground Truth"
df_template.insert(2, 'Related Triples', df_verbalization['Found Triples'])
df_template.insert(3, 'Context', df_verbalization['Processed Triples'])

df_template.to_excel('train_perfect.xlsx', index=False)

# %%
df_template['Context'][0]
# Out:
# 'Prof. Stefan Diebels has expertise in Computational materials science; PD Dr.  Franz  Roters has expertise in Computational materials science; Prof. Dr. Karsten  Durst has expertise in Computational Materials Science; Prof. Dr.-Ing. Stephan Wulfinghoff has expertise in Computational Materials Science; Christian Dorn has expertise in Computational Materials Science; Dr.-Ing Abril Azocar Guzman has expertise in Computational Materials Science; Prof. Dr.  Jörg Neugebauer has expertise in Computational Materials Science; PD Dr. habil.  Thomas Hammerschmidt has expertise in computational materials science; Dr Sarath Menon has expertise in computational materials science'
